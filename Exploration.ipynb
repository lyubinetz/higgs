# %% [markdown]
# # Data exploration

# %%
from helpers import *
import numpy as np
import pandas as pd

# %%
x = np.array([[1,2], [2,3]])
print(x * 2)
print(x)
# Out:
# [[2 4]
#  [4 6]]
# [[1 2]
#  [2 3]]

# %%
x = pd.read_csv('datasets/train.csv')
x.columns
# Out:
# Index(['Id', 'Prediction', 'DER_mass_MMC', 'DER_mass_transverse_met_lep',
#        'DER_mass_vis', 'DER_pt_h', 'DER_deltaeta_jet_jet', 'DER_mass_jet_jet',
#        'DER_prodeta_jet_jet', 'DER_deltar_tau_lep', 'DER_pt_tot', 'DER_sum_pt',
#        'DER_pt_ratio_lep_tau', 'DER_met_phi_centrality',
#        'DER_lep_eta_centrality', 'PRI_tau_pt', 'PRI_tau_eta', 'PRI_tau_phi',
#        'PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi',
#        'PRI_met_sumet', 'PRI_jet_num', 'PRI_jet_leading_pt',
#        'PRI_jet_leading_eta', 'PRI_jet_leading_phi', 'PRI_jet_subleading_pt',
#        'PRI_jet_subleading_eta', 'PRI_jet_subleading_phi', 'PRI_jet_all_pt'],
#       dtype='object')

# %%
x['DER_mass_MMC'] = x['DER_mass_MMC'].replace(to_replace=-999, value=np.NaN)
x.describe()
# Out:
#                   Id   DER_mass_MMC  DER_mass_transverse_met_lep  \
# count  250000.000000  211886.000000                250000.000000
# mean   224999.500000     121.858528                    49.239819
# std     72168.927986      57.298157                    35.344886
# min    100000.000000       9.044000                     0.000000
# 25%    162499.750000      91.885250                    19.241000
# 50%    224999.500000     112.406000                    46.524000
# 75%    287499.250000     135.482000                    73.598000
# max    349999.000000    1192.026000                   690.075000
#
#         DER_mass_vis       DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# count  250000.000000  250000.000000         250000.000000     250000.000000
# mean       81.181982      57.895962           -708.420675       -601.237051
# std        40.828691      63.655682            454.480565        657.972302
# ...

# %%
X_train, y_train = read_experiment_data('datasets/train.csv')
print('Total data size is ' + str(len(X_train)))
print('Number of columns is ' + str(len(X_train.columns)))
print(X_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a1ce64cc7242> in <module>()
# ----> 1 X_train, y_train = read_experiment_data('datasets/train.csv')
#       2 print('Total data size is ' + str(len(X_train)))
#       3 print('Number of columns is ' + str(len(X_train.columns)))
#       4 print(X_train)
#
# NameError: name 'read_experiment_data' is not defined

# %%
for col in X_train.columns:
    invalid = X_train[X_train[col] <= -999]
    if len(invalid) > 0:
        print('Column ' + str(col) + ' has ' + str(len(invalid)) + ' invalid values.')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-8c9ccb8e1fe0> in <module>()
# ----> 1 for col in X_train.columns:
#       2     invalid = X_train[X_train[col] <= -999]
#       3     if len(invalid) > 0:
#       4         print('Column ' + str(col) + ' has ' + str(len(invalid)) + ' invalid values.')
#
# NameError: name 'X_train' is not defined
