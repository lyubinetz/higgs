# %% [markdown]
# # Data exploration

# %%
from helpers import *

# %%
X_train, y_train = read_experiment_data('datasets/train.csv')
print('Total data size is ' + str(len(X_train)))
print('Number of columns is ' + str(len(X_train.columns)))
print(X_train)
# Out:
# Total data size is 250000
# Number of columns is 31
#             Id  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# 0       100000       138.470                       51.655        97.827
# 1       100001       160.937                       68.768       103.235
# 2       100002      -999.000                      162.172       125.953
# 3       100003       143.905                       81.417        80.943
# 4       100004       175.864                       16.915       134.805
# 5       100005        89.744                       13.550        59.149
# 6       100006       148.754                       28.862       107.782
# 7       100007       154.916                       10.418        94.714
# 8       100008       105.594                       50.559       100.989
# 9       100009       128.053                       88.941        69.272
# 10      100010      -999.000                       86.240        79.692
# ...

# %%
for col in X_train.columns:
    invalid = X_train[X_train[col] <= -999]
    if len(invalid) > 0:
        print('Column ' + str(col) + ' has ' + str(len(invalid)) + ' invalid values.')
# Out:
# Column DER_mass_MMC has 38114 invalid values.
# Column DER_deltaeta_jet_jet has 177457 invalid values.
# Column DER_mass_jet_jet has 177457 invalid values.
# Column DER_prodeta_jet_jet has 177457 invalid values.
# Column DER_lep_eta_centrality has 177457 invalid values.
# Column PRI_jet_leading_pt has 99913 invalid values.
# Column PRI_jet_leading_eta has 99913 invalid values.
# Column PRI_jet_leading_phi has 99913 invalid values.
# Column PRI_jet_subleading_pt has 177457 invalid values.
# Column PRI_jet_subleading_eta has 177457 invalid values.
# Column PRI_jet_subleading_phi has 177457 invalid values.
